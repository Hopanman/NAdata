# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_location='c:/Windows/fonts/malgun.ttf'
font_name=font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)

# %%
pd.set_option('max_column',None)

# %%
movie = pd.read_csv('movie_regression.csv',encoding='cp949')

# %%
movie
# Out:
#                                   TITLE      DIRECTOR     OPEN_DT  OPEN_YEAR  \
# 0                                    명량           김한민  2014-07-30       2014
# 1                                  극한직업           이병헌  2019-01-23       2019
# 2                             신과함께-죄와 벌           김용화  2017-12-20       2017
# 3                                  국제시장           윤제균  2014-12-17       2014
# 4                                   베테랑           류승완  2015-08-05       2015
# 5                                   도둑들           최동훈  2012-07-25       2012
# 6                               7번방의 선물           이환경  2013-01-23       2013
# 7                                    암살           최동훈  2015-07-22       2015
# 8                           광해, 왕이 된 남자           추창민  2012-09-13       2012
# 9                             신과함께-인과 연           김용화  2018-08-01       2018
# 10                                택시운전사            장훈  2017-08-02       2017
# ...

# %%
movie.groupby('OPEN_YEAR')['AUDI_ACC'].sum().plot(kind='bar')

# %%
sns.set_style("white")

# %%
sns.set_palette('RdBu')

# %%
sns.catplot(x='OPEN_YEAR',y='AUDI_ACC',data=movie)
# plt.ylim(ymin=-250000)
# plt.xlabel('개봉요일')
# plt.ylabel('관객수')
# plt.xticks([0,1,2,3,4,5,6],['월요일','화요일','수요일','목요일','금요일','토요일','일요일'])
# plt.yticks([0,5000000,10000000,15000000,20000000],['0','500만명','1000만명','1500만명','2000만명'])

# %%
plt.xticks?

# %%
sns.catplot(x='OPEN_WEEK',y='AUDI_ACC',data=movie)
plt.ylim(ymin=-250000)
# Out:
# (-250000, 20000000.0)

# %%
plt.xlabel?
